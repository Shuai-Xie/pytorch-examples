# %%
import gym
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
env = gym.make('FrozenLake-v0', is_slippery=False)  # Deterministic
env.reset()
env.render()  
# 显示当前 state 处理 Start 位置
# S:START, G:GOAL, H:HOLE, F:FROZEN
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
# 随机选 action，实测发现，很容易掉坑里
def random_play_frozen_lake():
    while True:
        reward = 0.
        
        # 上限 100 次
        for t in range(100):
            print("\nTimestep {}".format(t))

            # 随机选择 a
            a = env.action_space.sample()
            observation, reward, done, _ = env.step(a)
            print(f'action: {a}, observation: {observation}, reward: {reward}')
            env.render()  # 显示当前 state

            if done:
                print("\nEpisode terminated early")
                break

        # 直到玩到 1个正确结果，break
        if reward > 0:
            break

# %%
random_play_frozen_lake()
# Out:
# Timestep 0
# action: 2, observation: 1, reward: 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Timestep 1
# action: 0, observation: 0, reward: 0.0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Timestep 2
# action: 2, observation: 1, reward: 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Timestep 3
# action: 2, observation: 2, reward: 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Timestep 4
# action: 1, observation: 6, reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Timestep 5
# action: 2, observation: 7, reward: 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# ...
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 0, observation: 7, reward: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 1, observation: 7, reward: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 2, observation: 7, reward: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
#
# Timestep 0
# action: 3, observation: 7, reward: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e5ad1c3dff61> in <module>
# ----> 1 random_play_frozen_lake()
#
# <ipython-input-3-b219eb69c2b6> in random_play_frozen_lake()
#       8             a = env.action_space.sample()  # 随机选择 a，虽然选定了1个 a，但有 33% 概率滑向 左右
#       9             observation, reward, done, _ = env.step(a)
# ---> 10             print(f'action: {a}, observation: {observation}, reward: {reward}')
#      11             env.render()  # 显示当前 state
#      12
#
# ~/anaconda3/envs/al/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/anaconda3/envs/al/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/anaconda3/envs/al/lib/python3.6/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/anaconda3/envs/al/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# 4个方向 对应的 index
actions = {'Left': 0, 'Down': 1, 'Right': 2, 'Up': 3}

# 正确的 action 序列
good_plan = ['Right'] * 2 + ['Down'] * 3 + ['Right']

# 重置环境
env.reset()

for a in good_plan:
    new_state, reward, done, info = env.step(actions[a])
    print(f'\naction: {a}, observation: {new_state}, reward: {reward}')
    env.render()
    if done:  # reward = 1.0
        print("\nEpisode terminated early")
        break
# Out:
# action: Right, observation: 1, reward: 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# action: Right, observation: 2, reward: 0.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# action: Down, observation: 6, reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# action: Down, observation: 10, reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# action: Down, observation: 14, reward: 0.0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#
# action: Right, observation: 15, reward: 1.0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#
# Episode terminated early
